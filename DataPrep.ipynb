# %%
import pandas as pd

# %%
data = pd.read_csv("nasa.csv")

# %%
data.columns
# Out:
# Index(['Neo Reference ID', 'Name', 'Absolute Magnitude', 'Est Dia in KM(min)',
#        'Est Dia in KM(max)', 'Close Approach Date',
#        'Epoch Date Close Approach', 'Relative Velocity km per sec',
#        'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Orbit ID', 'Orbit Determination Date',
#        'Orbit Uncertainity', 'Minimum Orbit Intersection',
#        'Jupiter Tisserand Invariant', 'Epoch Osculation', 'Eccentricity',
#        'Semi Major Axis', 'Inclination', 'Asc Node Longitude',
#        'Orbital Period', 'Perihelion Distance', 'Perihelion Arg',
#        'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly', 'Mean Motion',
#        'Equinox', 'Hazardous'],
#       dtype='object')

# %%
data.rename(
    columns={"Est Dia in KM(min)": "Estimated Diameter in Kilometers (min)",
             "Est Dia in KM(max)": "Estimated Diameter in Kilometers (max)",
             "Relative Velocity km per sec": "Relative Velocity (km/s)", 
             "Miss Dist.(Astronomical)": "Miss Distance in Astronimical Units (AU)",
             "Miss Dist.(lunar)": "Miss Distance in Lunar Distance (LD)",
             "Miss Dist.(kilometers)": "Miss Distance in Kilometers",
             "Asc Node Longitude": "Ascending Node Longitude",
             "Perihelion Arg": "Perihelion Argument",
             "Aphelion Dist": "Aphelion Distance",
             "Eccentricity": "Orbit Eccentricity",
             "Semi Major Axis": "Orbit Semi-Major Axis",
             "Inclination": "Orbit Inclination"},
    inplace=True,
)

# %%
data.columns
# Out:
# Index(['Neo Reference ID', 'Name', 'Absolute Magnitude',
#        'Estimated Diameter in Kilometers (min)',
#        'Estimated Diameter in Kilometers (max)', 'Close Approach Date',
#        'Epoch Date Close Approach', 'Relative Velocity (km/s)',
#        'Miss Distance in Astronimical Units (AU)',
#        'Miss Distance in Lunar Distance (LD)', 'Miss Distance in Kilometers',
#        'Orbit ID', 'Orbit Determination Date', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Orbit Eccentricity', 'Orbit Semi-Major Axis',
#        'Orbit Inclination', 'Ascending Node Longitude', 'Orbital Period',
#        'Perihelion Distance', 'Perihelion Argument', 'Aphelion Distance',
#        'Perihelion Time', 'Mean Anomaly', 'Mean Motion', 'Equinox',
#        'Hazardous'],
#       dtype='object')

# %%
data
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  \
# 0              3703080  3703080              21.600
# 1              3723955  3723955              21.300
# 2              2446862  2446862              20.300
# 3              3092506  3092506              27.400
# 4              3514799  3514799              21.600
# ...                ...      ...                 ...
# 4682           3759007  3759007              23.900
# 4683           3759295  3759295              28.200
# 4684           3759714  3759714              22.700
# 4685           3759720  3759720              21.800
# 4686           3772978  3772978              19.109
#
#       Estimated Diameter in Kilometers (min)  \
# 0                                   0.127220
# 1                                   0.146068
# 2                                   0.231502
# 3                                   0.008801
# 4                                   0.127220
# ...                                      ...
# ...

# %%
data.to_csv("nasa.csv")
